# %% [markdown]
# # 범위
# ## 1
# ### 딥러닝 기초
# - 퍼셉트론
# - MLP (Multi Layer Perceptron)
# - 활성화 함수
# - 손실 함수
#
# ### 신경망 학습
# - 경사하강법
# - 역전파 원리
#
# ### 파이썬 라이브러리 소개
# - Numpy
# - matplotlib
# - PyTorch
#
# ### 예제
# - PyTorch 신경망 구현
#
# ## 2
# ### 딥러닝
# - Optimizer
# - 과적합
# - 하이퍼파라미터
#
# ### 예제
# - 하이퍼파라미터 vs Loss
#
# ## 3
# ### 하이퍼파라미터 튜닝
# - Optuna
# ### 파이썬
# - Class 구조
# - PyTorch: Tensor, Autograd, nn.Module
# - 데이터 다루기: Dataset, DataLoader
# - GPU 학습
#
# ## 4 ~
# - Physics-Informed Neural Network
# - Deep Operator Network
# - etc.
